# %% [markdown]
# # 1. Overview: Preprocessing Notebook
# This notebook preprocesses election contribution data and shapefiles from https://open-data.bouldercolorado.gov/, and creates preliminary visualizations with Uber's H3 API https://h3geo.org/docs/. Radar's geocoding API is used to gather lat/lon pairs from record addresses https://radar.com/product/geocoding-api. Finally, functions are defined throughout the notebook to make it clearer as to what's being used, when, and why.
#
# Listed below are a few of the core problems tackled throughout this notebook:
# 1) "City" feature cleaning
#     - Donations to elections can span the entire country; there are no restrictions on who can and cannot give money. Because of this, we see many donations that fall outside of Boulder's city limits. Since this analysis is only interested in donations from Boulder proper, it's important to filter donations.
#     - Human error is rampant in this dataset, leading to records with misspellings of "Boulder", empty values for State and Zip columns, and more. The city spelling in particular takes quite a bit of work to reconstruct. A class named *Matcher* was created to identify all Boulder entries regardless of spelling. There are more advanced string matching options and packages, but this was a nice opportunity to demonstrate custom code.
# 2) Record identification
#     - Even after proper city names were recovered, the problem of missing and misspelled state and zip columns remained. Layered logic repaired these records leading to a largely clean dataset. The output is not perfect, but it's "good enough" for the next step.
# 3) Geocoding
#     - Correct addresses aren't very helpful without lat/lon pairs when mapping data. As a solution, Custom functions are built to call Radar's geocoding API which returns a formatted address and a lat/lon pair. Note that performance is poor since batch requests are not allowed with a free account. In a production-setting, this code would be altered significantly to improve overall speed.
#
#
# Finally, a handful of H3 visualizations are included to view contributions across the city. H3 is an open-source package with several advantages, many of which are discussed at length on their blog and in documentation. I prefer H3 to geohash or S2, because hexagons (and their associated "rings" which surround them) are roughly a circle. This has advantages when creating radius-based features such as contributions_within_15_miles.$^{*}$
#
# <font size="2">
# $^{*}$ H3-specific notebooks in my repo go into greater detail
# </font>

# %% [markdown]
# ___

# %% [markdown]
# ## 1.1 Package Imports & Dataload

# %%
import pandas as pd
import math
import numpy as np
import json
import requests
import time
import re
import geopandas as gpd
from shapely.ops import transform
from shapely import Point, Polygon
import h3

# %%
# if we were using AWS 
# import awswrangler as wr 
# df = wr.s3.read_csv(S3_PATH)

# %%
# import csv
df = pd.read_csv('election_amounts.csv')
# view all cities
df.City.unique()
# Out:
# array(['Boulder', 'Longmont', 'BOULDER', 'Chicago', 'Ward', 'boulder',
#        'Denver', nan, 'Olney', 'Ann Arbor', 'Nederalnd', 'Superior',
#        'Lafayette', 'Nederland', 'Littleton', 'B', 'Arvada', 'Louisville',
#        'Bouler', 'Champaign', 'BOulder', 'Erie', 'Santa Cruz', 'Lyons',
#        'Fort Collins', 'Westminster', 'Austin', 'Orinda', 'Anahein',
#        'Bolder', 'Asheville', 'Charlottesville', 'Nederland ', 'Oakland',
#        'Anaheim', 'Boulder ', 'Firestone', 'Greenwood Village',
#        'Broomfield', '50', 'Greenwich', 'Greenville', 'Washington',
#        'Coc Cob', 'Portland', 'Westport', 'Rye', 'Burdett', 'Valparaiso',
#        'Albion', 'Romulus', 'Englewood', 'la', 'montclair', 'maimi beach',
#        'longmont', 'miami', 'Westminister', 'Columbia', 'Maricopa',
#        'Gainsville', 'Trumansburg', 'Niwot', 'Vilas', 'West Chester',
#        'online', 'gypsum', 'chandler', 'sausalito',
#        'Dulwich Hill NSW, Au', 'Dulwich, NSW Austral', 'Dulwich Hill NSW',
#        'woodland park', 'coulder', 'miami beach', 'tampa', 'ledgewood',
#        'Greenwood', 'Atlanta', 'Longmont ', 'Providence', 'Baton Rouge',
#        'Vero Beach', 'Glyndon', 'Kansas City', 'Pittsburg', 'Madison',
#        'Lakewood', 'Bouldera', 'Traverse City', 'Ft Collins',
#        'Takoma Park', 'Silverthorne', 'Parker', 'Durham', 'Camino',
#        'Hingham', 'Dillon', 'Mancos', 'Las Cruces', 'Craig', 'Durango',
#        'Telluride', 'Boise', 'Sacramento', 'Bouder', 'Broomfield ',
#        'Arlington', 'Honolulu', 'St Louis', 'Taakoma Park', 'Centennial',
#        'Lakewwod', 'broomfield', 'denver', 'mt laurel', 'Cherry Hill',
#        'Philadelphia', 'Edgewater', 'South Hampton', 'San Jose',
#        'Seaside', 'Aurora', 'Cherry Hill ', 'lafayette', 'Boudler',
#        'Layton', 'Bouldr', 'Fairfield', 'Port Orchard', 'Lubblock',
#        'Dallas', 'Tucson', 'Queens', 'Orlando', 'Owings', 'Laramie',
#        'Winston Salem', 'Santa Monica', 'Franklin', 'Morrison',
#        'Sterling', 'xxx', 'St Albans', 'Normal', 'Wooster', 'Willits',
#        'New York', 'Hermosa Beach', 'Olympia', 'Apharetta',
#        'Spring Lake ', 'Wesley Chapel', 'Malmo SWEDEN', 'Ottawa Ontario',
#        'Scarsdale', 'Richmond Ht', 'Los Angeles', 'Urbana',
#        'Saxtons River', 'Eugene', 'Skokie', 'Mt Holly', 'Kelso',
#        'Northglenn', 'Windsor', 'Bouldewwr', 'Alexandria', 'Watervliet',
#        'lakewood', 'Thornton', 'San Francisco', 'Brooklyn ',
#        'Albuquerque', 'Glendale', 'Jamestown', 'Richmond', 'ft. collins',
#        'Minneapolis', 'Allenspark', '80303', 'Goleta', 'Douglasville',
#        'new orleans', 'Aspen', 'buolder', 'Richfield', 'Memphis',
#        'Knoxville', 'Hastings', 'McPherson', 'Boul;der', 'Seattle',
#        'Carrollton', 'Como', 'Nashville', 'Golden', 'Phoenixville',
#        'columbia', 'Rockville', 'Laurel Fork', 'JAMESTOWN', 'Atherton',
#        'St. Paul', 'Victoria, CANADA', 'New York City', 'Erith',
#        'Penn Valley', 'Kilauea', 'Dutch Harbor', 'Towradgi, Australia',
#        'Sanford', 'Soap Lake', 'West Hollywood', 'Santa Clara',
#        'Appleton', 'Bloomington', 'Zephyr Cove', 'Okeechobee', 'Temple',
#        'Aiken', 'McMinnville', 'Innisfil', 'Purdys', 'NY', 'Marblehead',
#        'Rochester Hills', 'Oviedo', 'Boston', 'Missoula', 'London, UK',
#        'Wasilla', 'St. Albert, AB', 'Hilton, Australia', 'Canberra, ACT',
#        'Fayetteville', 'Somerville', 'Hudson', 'Woodland Park',
#        'Sunnyvale', 'Crested Butte', 'Halifax, Nova Scotia',
#        'Perth, Australia', 'Cupertino', 'Auckland', 'Bellbrook',
#        'Silver Spring', 'Anonymous', 'Washington ', 'Grand Junction ',
#        'Cincinnati', 'San Francisco ', 'Decatur', 'Carrollton ',
#        'Sugar Land', 'Pagosa Springs', 'Miami', 'Prescott', 'Montgomery',
#        'Monument ', 'Worcester', 'Flagstaff', 'Beaverton', 'Cheyenne',
#        ' Boulder ', 'Boulde', 'Grand Junction', 'Hillsdale', 'Loveland',
#        'El Paso', 'Santa Fe', 'Colorado Springs', 'Ruckersville',
#        'Cherry Hills Village', 'Bixby', 'Menlo Park', 'Robesonia',
#        'TUCSON', 'Palo Alto', 'PORTLAND', 'WASHINGTON', 'SEATTLE',
#        'Berkeley', 'Claremont', 'Santa Barbara', 'Montebello',
#        'Monroe Township', 'Houston', 'San Antonio', 'Redondo Beach',
#        'Chico', 'Ardmore', 'bulder', 'indiegogo', 'Lousville',
#        '9/10/2015', 'Overland', '10/1/2015', 'golden', 'san rafael',
#        'Bouilder', 'Salt Lake City', 'Richardson', 'Lawrence', 'Salina',
#        'Irvine', 'La Quinta', 'Stratford', 'Redwood City', 'Wichita',
#        'Frisco', 'McLean', 'Firesetone', 'Hollady', 'Cary', 'Cambridge',
#        'Sparta', 'Indianapolis', 'Boulder County', 'Bethesda', 'Snelling',
#        'Kensington', 'Mount Holly', 'Las Vegas', 'Towson', 'Nutley',
#        'Rockaway', 'jamestown', 'Manitou Springs', 'Bronxville', 'oulder',
#        'Brooklyn', 'Devner', 'Bayonne', 'Bozman', 'Vail', 'Darien',
#        'Helena', 'Noulder', 'Princeton', 'Whitefish Bay', 'Stow',
#        'Berkley', 'Cerritos', 'Port Clyde', 'Ithaca', 'Billings',
#        'Maplewood', 'Del Ray Beach', 'jLos Angeles', 'Pottstown',
#        'Great Falls', 'Chandler', 'Lousiville', 'Be lAir', 'Oyster Bay',
#        'Aventura', 'Orchard Lake', 'Mutton Town', 'Wynnewood',
#        'Framingham', 'Newton', 'Jersey City', 'Sunnyside', 'Scottsdale',
#        'Jamaica Plain', 'DENVER', 'Basalt', 'Breckenridge', 'Bellevue',
#        'Nerinx', 'Ft. Collins', 'Lone Tree', 'PROSPECT', 'SAN FRANCISCO',
#        'SAN FRANSISCO', 'Scotts Valley', 'Eldorado Springs',
#        'Carbondale ', 'Clayton', 'Libertyville', ' Germantown ',
#        'Orland Park', 'Sarasota', 'Boulder-CO', ', Boulder', 'De Pere',
#        'Notre Dame', 'Shepherdsville', ' Boulder', 'BROOMFIELD',
#        ' Lafayette', 'APO, AE 09630-0032', 'Phoenix', 'Roseville',
#        'San Pablo', 'Suamico', 'Green Bay', 'Beverly Hills', 'Rosendale',
#        'Manitowac', 'Yakima', 'San Juan', 'Venice', 'Edina',
#        'Franksville', 'Syracuse', 'Syracuse, NY ', 'Syracuse, NY',
#        'Tiburon', 'Wyomissing', 'East Northport', 'Sherwood Forest',
#        'Fresno', 'Alamo', 'Plainsboro', 'North Barrington', 'Excelsior',
#        ' Lisle', 'FORT COLLINS', 'Minnetonka', 'South Yarmouth',
#        'Boukder', 'Davidsonville', 'Saint Louis', 'Tampa', 'Wildwood',
#        'Healdsburg', 'West St Paul', 'Carlisle', 'Creve Coeur',
#        'Succasunna', 'Thousand Oaks', 'Ashland', '90049', 'Pine',
#        'Sammamish', 'NIWOT', 'LOUISVILLE', 'CHAPEL HILL', 'LONGMONT',
#        'LAFAYETTE', 'Versailles', 'LYONS', 'Ketchum', 'Steamboat Springs',
#        "O'Fallon", 'Land O Lakes', 'Gilroy', 'Pasadena', 'Tulsa',
#        'Chapel Hill', '10/6/2017', 'Redding', 'Highlands Ranch',
#        'Buena Vista', 'Malibu', 'Eroe', 'East Hampton', 'Garden City',
#        'Mount Arlington', 'Pacific Palisade', 'Torrance', 'LEES SUMMIT',
#        'St. Louis', 'Southgate', 'Iowa City', 'Crofton', 'New Haven',
#        'Bouldwer', 'Baton ROuge', 'Bouldewr', 'San Antonio ', 'Stanford',
#        'xx', 'oOulder', 'Belleville', 'littleton', 'bOUlder', 'Caledonia',
#        'Holiday', 'Nichols Hills', 'Roswell', 'Santa Monica ',
#        'Williamsburg', 'Ojai', 'Howell', 'Black Hawk', 'Niwot ', 'Toano',
#        'Merrimac', 'Aptos', 'Grand Rapids', 'Hygiene', 'Laredo',
#        'Crown Point', 'Oak Brook', 'Lohgmont', 'Leawood', 'Ft. Lupton',
#        'Paonia', 'Mercer Island', 'Saint John', 'Milwaukee', 'Maitland',
#        'Avon', 'Montclair', 'Davis', 'Bellaire', 'Palm Beach', 'Basalt ',
#        'Gilbert', 'Bouolder', 'bolder', 'Princeville', 'bouulder',
#        'Pelham', 'Boulder  ', 'Bluff', 'bouder', 'Livermore', 'atlanta'],
#       dtype=object)

# %% [markdown]
# We only want to consider "Boulder" along with its associated misspellings. In order to do this, we'll implement fuzzy matching. A custom matching method is created below because of the interest in matching a static dataset against a static word. A productionized solution for many different city names would require a more sophisticated approach.

# %% [markdown]
# ___

# %% [markdown]
# ## 1.2 City Cleaning

# %% [markdown]
# #### Idea: Match = Minimum Number of *Matching* Characters Met
# - The class below is involved, but at its core it defines a match when
#     - **1)** >75% of the characters are matched and
#     - **2)** when the word we are checking is within 1 character (in terms of length) from the base word.
# - self.duplicate is created for letters_in_common and threshold_met
#     - If we have duplicate letters in a word, the more performant set logic breaks down. In this case we'll fall back to list logic.

# %%
class Matcher:
    '''
    We define a class with a base word and an identifier "duplicate".
    If duplicate is true, meaning there are duplicate letters within a word,
    then we use the list logic in letters_in_common. If duplicate is false,
    then we use the set logic which has greater performance. By instantiating the
    class, we automatically create the duplicate variable opposed to checking
    for duplicates every time within letters_in_common.
    '''
    def __init__(self, base_word):
        self.base_word = base_word.lower()
        self.base_word_length = len(base_word)
        self.duplicate = False if len(set(base_word))==len(list(base_word)) else True
        
    def stringify(self, to_check):
        '''
        Preprocess to_check to address situations like:
        1. 'boulder-CO'
        2. '   boulder '
        3. nan
        4. <int>/<float>
        '''
            # First, check if to_check is a string and not NaN
        if pd.isna(to_check):
            return ''  # Return an empty string for NaN values
        elif isinstance(to_check, str):
            stripped = to_check.strip()
            if stripped:  # Check if the string is not empty after stripping
                return stripped.split()[0].lower()
            else:
                return '' 
        else:
            return ''  
        
    def letters_in_common(self, to_check):
        to_check = self.stringify(to_check)
        if self.duplicate:
            return len([x for x in to_check if x in self.base_word])
        else:
            return len(set(self.base_word).intersection(set(to_check)))
    
    def threshold_met(self, to_check, threshold=0.75):
        to_check = self.stringify(to_check)
        if self.duplicate:
            return True if len([x for x in to_check if x in self.base_word])/self.base_word_length > threshold else False
        else:
            return True if len(set(self.base_word).intersection(set(to_check)))/self.base_word_length > threshold else False
        
    def length_req_met(self, to_check, diff=1):
        to_check = self.stringify(to_check)
        return True if int(abs(self.base_word_length-len(to_check))) <= int(diff) else False
        
    def common_word(self, to_check):
        to_check = self.stringify(to_check)
        return True if (self.length_req_met(to_check) and self.threshold_met(to_check)) else False

# %%
m = Matcher('Boulder')
df.loc[df['City'].apply(lambda x: m.common_word(x))].City.unique()
# Out:
# array(['Boulder', 'BOULDER', 'boulder', 'Bouler', 'BOulder', 'Bolder',
#        'Boulder ', 'coulder', 'Bouldera', 'Bouder', 'Boudler', 'Bouldr',
#        'buolder', 'Boul;der', ' Boulder ', 'Boulde', 'bulder', 'Bouilder',
#        'Boulder County', 'oulder', 'Noulder', ' Boulder', 'Boukder',
#        'Bouldwer', 'Bouldewr', 'oOulder', 'bOUlder', 'Bouolder', 'bolder',
#        'bouulder', 'Boulder  ', 'bouder'], dtype=object)

# %% [markdown]
# Seeing 'Boulder County', it's clear that checking only for city name matches still leaves errors. There are three other avenues we can expand into for greater accuracy (we will only look at 1 and 2, since 3 is out of scope for this exercise):
#
# 1) Check for State
#     - Rather simple; all states must = CO
# 2) Check for Zip
#     - Given a list of all Boulder ZIPs
# 3) Match street name
#     - It should be possible to take every street name and, with a google maps API or something similar, see of the address exists within Boulder. This presents a host of other problems since street addresses are highly repetitive across the country and are subject to change. This option won't be investigated.
#
# Given that we will be plotting lat/lon data generated from (street, city, state, zip) tuples, it's important that we have all of these features present and largely accurate. It seems unlikely that an individual would leave out both State and ZIP from their donation, so we'll add binary indicators for each of these columns. We'll also add a binary indicator for City. With these three binary indicators (and null street names dropped), logic can be implemented to keep all correct columns for Boulder-proper donations.
#
# At least two of State/City/Zip must match to be eligible for the final dataset. But first, we'll replace all city matches with "Boulder" and make sure that all state pairs for "Boulder" are "CO". Since Boulder is not a unique city name, we expose ourselves to associating (Boulder, other state) pairs with (Boulder, CO), however the likelihood of this is low and will be handled later when gathering lat/lons from addresses. Once this step is complete, indicator columns will be generated. From this point forward, all changes will be made to a copy of df.

# %% [markdown]
# ___

# %% [markdown]
# ## 1.3 City/State/Zip Filtering

# %%
# copy of df
cp = df.copy()

# city replacement
cp['City'] = cp['City'].apply(lambda x: 'Boulder' if m.common_word(x) else x)
cp['city_match'] = cp['City'].apply(lambda x: 1 if m.common_word(x) else 0)

# state replacement
## this creates cases where we can have (NaN, CO) city/state tuples. If zip==Boulder zip, we'll re-populate NaN cp.City with "Boulder"
cp['State'] = cp.apply(lambda x: 'CO' if x.city_match==1 else x.State, axis=1)
cp['state_match'] = cp['State'].apply(lambda x: 1 if isinstance(x, str) and str.strip(x).split()[0].lower()=='co' else 0)

# zip replacement
zips = ['80301', '80302', '80303', '80304', '80305', '80503', '80306', '80307', '80308', '80309', '80310', '80314']
cp['Zip'] = cp['Zip'].apply(lambda x: str.strip(x).split()[0] if isinstance(x, str) and str.strip(x).split()[0] in zips else x)
cp['zip_match'] = cp['Zip'].apply(lambda x: 1 if isinstance(x, str) and str.strip(x).split()[0] in zips else 0)

# match count
cp['match_count'] = cp.city_match + cp.state_match + cp.zip_match

# %%
# check for uniqueness given "Boulder"
cp.loc[cp['City'].apply(lambda x: m.common_word(x))].City.unique()
# Out:
# array(['Boulder'], dtype=object)

# %% [markdown]
# #### Restrict to 2 matches
# - output all unique (City, State, Zip) tuples

# %%
# restrict to 2 matches
cp = cp[cp.match_count>=2]
# output tuples
set(cp[['City', 'State', 'Zip']].itertuples(index=False))
# Out:
# {Pandas(City=', Boulder', State='CO', Zip='80302'),
#  Pandas(City='10/1/2015', State='CO', Zip='80304'),
#  Pandas(City='50', State='CO', Zip='80302'),
#  Pandas(City='80303', State='CO', Zip='80303'),
#  Pandas(City='9/10/2015', State='CO', Zip='80301'),
#  Pandas(City='B', State='CO', Zip='80302'),
#  Pandas(City='B', State='CO', Zip='80303'),
#  Pandas(City='B', State='CO', Zip='80304'),
#  Pandas(City='B', State='CO', Zip='80305'),
#  Pandas(City='Bluff', State='CO', Zip='80304'),
#  Pandas(City='Boulder', State='CO', Zip='100'),
#  Pandas(City='Boulder', State='CO', Zip='480305'),
#  Pandas(City='Boulder', State='CO', Zip='50'),
#  Pandas(City='Boulder', State='CO', Zip='8/3/2005'),
#  Pandas(City='Boulder', State='CO', Zip='80-305'),
#  Pandas(City='Boulder', State='CO', Zip='80023'),
#  Pandas(City='Boulder', State='CO', Zip='80027'),
#  Pandas(City='Boulder', State='CO', Zip='80034'),
#  Pandas(City='Boulder', State='CO', Zip='80202'),
#  Pandas(City='Boulder', State='CO', Zip='8030-4'),
#  Pandas(City='Boulder', State='CO', Zip='80300'),
#  Pandas(City='Boulder', State='CO', Zip='80301'),
#  Pandas(City='Boulder', State='CO', Zip='80301-2101'),
#  Pandas(City='Boulder', State='CO', Zip='80301-5926'),
#  Pandas(City='Boulder', State='CO', Zip='80302'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5824'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5833'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5857'),
#  Pandas(City='Boulder', State='CO', Zip='80302-7416'),
#  Pandas(City='Boulder', State='CO', Zip='80302-7836'),
#  Pandas(City='Boulder', State='CO', Zip='80303'),
#  Pandas(City='Boulder', State='CO', Zip='80303-1108'),
#  Pandas(City='Boulder', State='CO', Zip='80303-2953'),
#  Pandas(City='Boulder', State='CO', Zip='80303-3731'),
#  Pandas(City='Boulder', State='CO', Zip='80303-4730'),
#  Pandas(City='Boulder', State='CO', Zip='80303-9630'),
#  Pandas(City='Boulder', State='CO', Zip='80304'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0716'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0723'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0763'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0793'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0839'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0984'),
#  Pandas(City='Boulder', State='CO', Zip='80304-1713'),
#  Pandas(City='Boulder', State='CO', Zip='80304-1839'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2212'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2515'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2834'),
#  Pandas(City='Boulder', State='CO', Zip='80304-3223'),
#  Pandas(City='Boulder', State='CO', Zip='80304-3940'),
#  Pandas(City='Boulder', State='CO', Zip='80305'),
#  Pandas(City='Boulder', State='CO', Zip='80305-5530'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6610'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6729'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6820'),
#  Pandas(City='Boulder', State='CO', Zip='80306'),
#  Pandas(City='Boulder', State='CO', Zip='80306-0019'),
#  Pandas(City='Boulder', State='CO', Zip='80306-0141'),
#  Pandas(City='Boulder', State='CO', Zip='80306-1867'),
#  Pandas(City='Boulder', State='CO', Zip='80306-7951'),
#  Pandas(City='Boulder', State='CO', Zip='80307'),
#  Pandas(City='Boulder', State='CO', Zip='80308'),
#  Pandas(City='Boulder', State='CO', Zip='80308-0100'),
#  Pandas(City='Boulder', State='CO', Zip='80309'),
#  Pandas(City='Boulder', State='CO', Zip='80320'),
#  Pandas(City='Boulder', State='CO', Zip='8035'),
#  Pandas(City='Boulder', State='CO', Zip='80406'),
#  Pandas(City='Boulder', State='CO', Zip='80503'),
#  Pandas(City='Boulder', State='CO', Zip='8304'),
#  Pandas(City='Boulder', State='CO', Zip='8306'),
#  Pandas(City='Boulder', State='CO', Zip='Boulder'),
#  Pandas(City='Boulder', State='CO', Zip='no address'),
#  Pandas(City='Boulder', State='CO', Zip=nan),
#  Pandas(City='Boulder-CO', State='CO', Zip='80302'),
#  Pandas(City='Broomfield', State='CO', Zip='80306'),
#  Pandas(City='LONGMONT', State='CO', Zip='80503'),
#  Pandas(City='Lohgmont', State='CO', Zip='80503'),
#  Pandas(City='Longmont', State='CO', Zip='80302'),
#  Pandas(City='Longmont', State='CO', Zip='80503'),
#  Pandas(City='Niwot ', State='CO', Zip='80503'),
#  Pandas(City='Niwot', State='CO', Zip='80305'),
#  Pandas(City='Niwot', State='CO', Zip='80503'),
#  Pandas(City='longmont', State='CO', Zip='80503')}

# %% [markdown]
# #### Further Cleaning
# - 80503 is primarily Longmont, but does overlap with Boulder
#     - if 80503 and ~Boulder then we'll drop

# %%
# drop longmont 
cp = cp[~((cp.Zip.str.split().str[0]=='80503') & ~(cp.City.str.split().str[0]=='Boulder'))]

# %%
set(cp[['City', 'State', 'Zip']].itertuples(index=False))
# Out:
# {Pandas(City=', Boulder', State='CO', Zip='80302'),
#  Pandas(City='10/1/2015', State='CO', Zip='80304'),
#  Pandas(City='50', State='CO', Zip='80302'),
#  Pandas(City='80303', State='CO', Zip='80303'),
#  Pandas(City='9/10/2015', State='CO', Zip='80301'),
#  Pandas(City='B', State='CO', Zip='80302'),
#  Pandas(City='B', State='CO', Zip='80303'),
#  Pandas(City='B', State='CO', Zip='80304'),
#  Pandas(City='B', State='CO', Zip='80305'),
#  Pandas(City='Bluff', State='CO', Zip='80304'),
#  Pandas(City='Boulder', State='CO', Zip='100'),
#  Pandas(City='Boulder', State='CO', Zip='480305'),
#  Pandas(City='Boulder', State='CO', Zip='50'),
#  Pandas(City='Boulder', State='CO', Zip='8/3/2005'),
#  Pandas(City='Boulder', State='CO', Zip='80-305'),
#  Pandas(City='Boulder', State='CO', Zip='80023'),
#  Pandas(City='Boulder', State='CO', Zip='80027'),
#  Pandas(City='Boulder', State='CO', Zip='80034'),
#  Pandas(City='Boulder', State='CO', Zip='80202'),
#  Pandas(City='Boulder', State='CO', Zip='8030-4'),
#  Pandas(City='Boulder', State='CO', Zip='80300'),
#  Pandas(City='Boulder', State='CO', Zip='80301'),
#  Pandas(City='Boulder', State='CO', Zip='80301-2101'),
#  Pandas(City='Boulder', State='CO', Zip='80301-5926'),
#  Pandas(City='Boulder', State='CO', Zip='80302'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5824'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5833'),
#  Pandas(City='Boulder', State='CO', Zip='80302-5857'),
#  Pandas(City='Boulder', State='CO', Zip='80302-7416'),
#  Pandas(City='Boulder', State='CO', Zip='80302-7836'),
#  Pandas(City='Boulder', State='CO', Zip='80303'),
#  Pandas(City='Boulder', State='CO', Zip='80303-1108'),
#  Pandas(City='Boulder', State='CO', Zip='80303-2953'),
#  Pandas(City='Boulder', State='CO', Zip='80303-3731'),
#  Pandas(City='Boulder', State='CO', Zip='80303-4730'),
#  Pandas(City='Boulder', State='CO', Zip='80303-9630'),
#  Pandas(City='Boulder', State='CO', Zip='80304'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0716'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0723'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0763'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0793'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0839'),
#  Pandas(City='Boulder', State='CO', Zip='80304-0984'),
#  Pandas(City='Boulder', State='CO', Zip='80304-1713'),
#  Pandas(City='Boulder', State='CO', Zip='80304-1839'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2212'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2515'),
#  Pandas(City='Boulder', State='CO', Zip='80304-2834'),
#  Pandas(City='Boulder', State='CO', Zip='80304-3223'),
#  Pandas(City='Boulder', State='CO', Zip='80304-3940'),
#  Pandas(City='Boulder', State='CO', Zip='80305'),
#  Pandas(City='Boulder', State='CO', Zip='80305-5530'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6610'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6729'),
#  Pandas(City='Boulder', State='CO', Zip='80305-6820'),
#  Pandas(City='Boulder', State='CO', Zip='80306'),
#  Pandas(City='Boulder', State='CO', Zip='80306-0019'),
#  Pandas(City='Boulder', State='CO', Zip='80306-0141'),
#  Pandas(City='Boulder', State='CO', Zip='80306-1867'),
#  Pandas(City='Boulder', State='CO', Zip='80306-7951'),
#  Pandas(City='Boulder', State='CO', Zip='80307'),
#  Pandas(City='Boulder', State='CO', Zip='80308'),
#  Pandas(City='Boulder', State='CO', Zip='80308-0100'),
#  Pandas(City='Boulder', State='CO', Zip='80309'),
#  Pandas(City='Boulder', State='CO', Zip='80320'),
#  Pandas(City='Boulder', State='CO', Zip='8035'),
#  Pandas(City='Boulder', State='CO', Zip='80406'),
#  Pandas(City='Boulder', State='CO', Zip='80503'),
#  Pandas(City='Boulder', State='CO', Zip='8304'),
#  Pandas(City='Boulder', State='CO', Zip='8306'),
#  Pandas(City='Boulder', State='CO', Zip='Boulder'),
#  Pandas(City='Boulder', State='CO', Zip='no address'),
#  Pandas(City='Boulder', State='CO', Zip=nan),
#  Pandas(City='Boulder-CO', State='CO', Zip='80302'),
#  Pandas(City='Broomfield', State='CO', Zip='80306'),
#  Pandas(City='Longmont', State='CO', Zip='80302'),
#  Pandas(City='Niwot', State='CO', Zip='80305')}

# %%
# drop addresses 
cp = cp.dropna(subset=['Street']).reset_index(drop=True)

# %% [markdown]
# There are still some errors in the dataset, but it's much cleaner than when we started and largely looks good enough to plug into Radar's geocoder. NULL addresses are dropped since we can't recover lat/lons without these present.

# %% [markdown]
# ___

# %% [markdown]
# ## 1.4 Final Preprocessing

# %% [markdown]
# #### Radar Geocode API
# - The functions below all fold into *fill_address* which is used to populate address, lat, and lon.
# - If we were productionizing a workflow, many of these hard-coded values would be removed and replaced with arguments

# %%
def custom_filter(value):
    return value not in [None, 'nan', np.nan]

def geolocate(pre_address):
    headers = {
        'Authorization': auth,
    }
    
    query=f'{pre_address}&layers=address&limit=1&near=40.00533,-105.25555'
    url=f'https://api.radar.io/v1/geocode/forward?query={query}'   
    response = requests.get(url=url, headers=headers)
    
    if (response.json()['meta']['code']!=200) or (not response.json()['addresses']):
        return None
    else:
        return response.json()

def clean_street(row):
    # Define our conditions
    keywords = ['#', 'unit', 'apt']
    pattern = re.compile(r'(' + '|'.join(re.escape(keyword) for keyword in keywords) + ').*$', re.IGNORECASE)
    
    return re.sub(pattern, '', row).strip()
    
# fill address based on available information; return full address and lat/lon
def fill_address(row):
    if row.name % 500 == 0:
        print(f'ROWS COMPLETE: {row.name} | TIME: {time.time()-start}')
        
    # Clean Street
    row['Street'] = clean_street(str(row['Street']))
    
    # Build a partial address as a string
    pre_address = (' '.join(filter(custom_filter, [str(row['Street']), str(row['City']), str(row['State']), str(row['Zip'])]))).replace(' ', '+')
    
    # Attempt to geocode the partial address
    location = geolocate(pre_address)
    if location:
        return pd.Series([location['addresses'][0]['formattedAddress'],
                          location['addresses'][0]['latitude'],
                          location['addresses'][0]['longitude']])
    else:
        return pd.Series([None, None, None])


# load auth 
f = open('auth.txt', 'r')
auth = f.read()

# Apply the function to the DataFrame
start = time.time()
cp[['Full Address', 'Latitude', 'Longitude']] = cp.apply(fill_address, axis=1)
print(f'ROWS COMPLETE: {len(cp)} | TIME: {time.time()-start}')
# Out:
# ROWS COMPLETE: 0 | TIME: 0.009482145309448242
# ROWS COMPLETE: 500 | TIME: 153.06374716758728
# ROWS COMPLETE: 1000 | TIME: 313.90986013412476
# ROWS COMPLETE: 1500 | TIME: 476.0237412452698
# ROWS COMPLETE: 2000 | TIME: 646.268764257431
# ROWS COMPLETE: 2500 | TIME: 786.6126773357391
# ROWS COMPLETE: 3000 | TIME: 923.8980710506439
# ROWS COMPLETE: 3500 | TIME: 1075.9698433876038
# ROWS COMPLETE: 4000 | TIME: 1215.3671431541443
# ROWS COMPLETE: 4500 | TIME: 1345.1409602165222
# ROWS COMPLETE: 5000 | TIME: 1518.2834422588348
# ROWS COMPLETE: 5500 | TIME: 1646.832602262497
# ROWS COMPLETE: 6000 | TIME: 1787.4929921627045
# ROWS COMPLETE: 6500 | TIME: 1926.911333322525
# ROWS COMPLETE: 7000 | TIME: 2062.0605742931366
# ROWS COMPLETE: 7500 | TIME: 2204.4894511699677
# ROWS COMPLETE: 8000 | TIME: 2331.265037059784
# ROWS COMPLETE: 8042 | TIME: 2345.323178052902

# %%
# save since process is time consuming
cp.to_csv('radar_data.csv')

# %% [markdown]
# #### Spatial Join Geometries to City Limits Shapefile
# - Boulder proper city limits are loaded in an plotted
# - Geopandas spatial join ensures all lat/lon pairs fall within Boulder proper

# %%
def load_convert_shapefile(shapefile, geometry_col='geometry', epsg=4269, conv_epsg=4326):
    '''
    This function takes in a shapefile and returns a GeoDataFrame with the proper coordinates.
    '''
    # read in shapefile
    gdf = gpd.read_file(shapefile)
    
    # if the CRS is not set, set it to NAD83 (EPSG:4269) which is a typical default if missing (per google)
    if gdf.crs is None:
        gdf.set_crs(epsg=epsg, inplace=True)
        print(f'EPSG manually set to: {epsg}')
    else: 
        epsg = str(gdf.crs).split(':')[1]
        print(f'EPSG found: {epsg}')

    # convert to WGS84
    gdf = gdf.to_crs(epsg=conv_epsg)
    print(f'EPSG converted: {conv_epsg}')
    
    return gdf

def get_xy(x, y, z):
    '''
    Takes in multipolygon Z and removes z-coord
    '''
    return x, y

# %%
# shapefile path
shapefile = 'boulder/City_of_Boulder_City_Limits.shp'
gdf = load_convert_shapefile(shapefile)
bgdf = gpd.GeoDataFrame(geometry=[gdf.geometry.unary_union], crs=4326)
bgdf['geometry'] = bgdf['geometry'].apply(lambda x: transform(get_xy, x))
bgdf.explore()
# Out:
# EPSG found: 4326
# EPSG converted: 4326
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b1a9a884a7636178f8f1d759a61b2e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b1a9a884a7636178f8f1d759a61b2e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b1a9a884a7636178f8f1d759a61b2e1 = L.map(
#                 &quot;map_7b1a9a884a7636178f8f1d759a61b2e1&quot;,
#                 {
#                     center: [40.025700696197845, -105.23977486122877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7b1a9a884a7636178f8f1d759a61b2e1);
#
#
#
#
#
#             var tile_layer_0989a8cc23945142706f06e59b36af19 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b1a9a884a7636178f8f1d759a61b2e1);
#
#
#             map_7b1a9a884a7636178f8f1d759a61b2e1.fitBounds(
#                 [[39.956916683424616, -105.30145090705521], [40.094484708971066, -105.17809881540231]],
#                 {}
#             );
#
#
#         function geo_json_b016486de854e68bd1c80d04a848ecf6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b016486de854e68bd1c80d04a848ecf6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b016486de854e68bd1c80d04a848ecf6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b016486de854e68bd1c80d04a848ecf6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b016486de854e68bd1c80d04a848ecf6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b016486de854e68bd1c80d04a848ecf6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b016486de854e68bd1c80d04a848ecf6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b016486de854e68bd1c80d04a848ecf6 = L.geoJson(null, {
#                 onEachFeature: geo_json_b016486de854e68bd1c80d04a848ecf6_onEachFeature,
#
#                 style: geo_json_b016486de854e68bd1c80d04a848ecf6_styler,
#                 pointToLayer: geo_json_b016486de854e68bd1c80d04a848ecf6_pointToLayer
#         });
#
#         function geo_json_b016486de854e68bd1c80d04a848ecf6_add (data) {
#             geo_json_b016486de854e68bd1c80d04a848ecf6
#                 .addData(data)
#                 .addTo(map_7b1a9a884a7636178f8f1d759a61b2e1);
#         }
#             geo_json_b016486de854e68bd1c80d04a848ecf6_add({&quot;bbox&quot;: [-105.30145090705521, 39.956916683424616, -105.17809881540231, 40.094484708971066], &quot;features&quot;: [{&quot;bbox&quot;: [-105.30145090705521, 39.956916683424616, -105.17809881540231, 40.094484708971066], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-105.21243674793588, 40.017318557813525], [-105.21365169960994, 40.017450673214526], [-105.21343695825585, 40.0175389874911], [-105.21327392906088, 40.017606034022904], [-105.2131571887651, 40.0176540439686], [-105.21301216364152, 40.017763877212396], [-105.2128801880404, 40.01786382566816], [-105.21268567179995, 40.018011137556385], [-105.21251718394

# %%
# create Point geometry
cp['geometry'] = cp.apply(lambda x: Point(x.Longitude, x.Latitude), axis=1)

# create final dataframe
cpf = cp.copy()
cpf = gpd.GeoDataFrame(cpf, geometry='geometry', crs=4326)

# inner spatial join with boulder polygon
cpf = cpf.sjoin(bgdf, how='inner').drop(columns='index_right')

# %% [markdown]
# ___

# %% [markdown]
# ## 1.5 Preliminary H3 Output
# - Resolution 9 hexagons are used which correspond to a diameter of 1/4mi
# - generate_shapefile_h3_cells() is based on a function I created for use in production pipelines
#     - h3.polygon_to_cells() will only keep hexagons with majority overlap on the Polygon in question. This results in many edge hexagons being removed from the dataset. The "exterior hexagons" portion pulls these edge hexagons back into the dataset.

# %%
def generate_shapefile_h3_cells(gdf, resolution):
    '''
    A GeoDataFrame is inserted with polygons spanning some geography. We fill that geography with H3 
    hexagons at a given resolution.
    '''
    
    h3_cell_ids = []
    polyct = 0
    multipolyct = 0
    
    for cell in gdf.geometry: 

        # check to see if the geometry is a polygon or multipolygon
        if cell.geom_type == 'Polygon': 
            # list to gather coordinates and exterior hexagons
            coords = []
            outer_hex_ids = []

            # iterate over coordinates in each polygon
            for coord in cell.exterior.coords: 
                # reverse lat/lon order for H3
                coords.append(tuple((coord[1], coord[0])))
                
                # exterior hexagons
                outer_hex_ids.append(h3.latlng_to_cell(coord[1], coord[0], resolution))

            # get interior and partial exterior hexagons
            inner_hex_ids = list(h3.polygon_to_cells(h3.Polygon(coords), resolution))

            # add all hexagons to hex_id list
            h3_cell_ids += list(set(outer_hex_ids)) + inner_hex_ids

            # add to poly counter 
            polyct += 1

        else: 
                
            # iterate over every polygon within the multipolygon
            for idx, poly in enumerate(cell.geoms):
                # list to gather coordinates and exterior hexagons
                coords = []
                outer_hex_ids = []
                
                # iterate over coordinates in each polygon
                for coord in poly.exterior.coords:
                    # reverse lat/lon order for H3
                    coords.append(tuple((coord[1], coord[0])))
                    
                    # exterior hexagons
                    outer_hex_ids.append(h3.latlng_to_cell(coord[1], coord[0], resolution))

                # get interior and partial exterior hexagons
                inner_hex_ids = list(h3.polygon_to_cells(h3.Polygon(coords), resolution))
                
                # add all hexagons to hex_id list
                h3_cell_ids += list(set(outer_hex_ids)) + inner_hex_ids

            # add to multipoly counter
            multipolyct += 1 

    print(f'------RESOLUTION {resolution}------')
    print(f'H3 Hexagons Generated: {len(set(h3_cell_ids))}')
    print(f'MultiPolygons: {multipolyct}')
    print(f'Polygons: {polyct}')
    print('\n')

    return list(set(h3_cell_ids))

# %%
cells = generate_shapefile_h3_cells(bgdf, 9)
# Out:
# ------RESOLUTION 9------
# H3 Hexagons Generated: 776
# MultiPolygons: 1
# Polygons: 0

# %%
# hexagons lat/lng must be flipped for accurate plotting
def flip(x,y):
    return y,x
geoms = [transform(flip, Polygon(h3.cell_to_boundary(cell))) for cell in cells]

# %%
hexes = gpd.GeoDataFrame(pd.DataFrame(list(zip(cells, geoms)), columns=['hex_id', 'geometry']), geometry='geometry', crs=4326)
hexes.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fc5aac50b1f91b6bbaaae88e08e5a88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fc5aac50b1f91b6bbaaae88e08e5a88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fc5aac50b1f91b6bbaaae88e08e5a88 = L.map(
#                 &quot;map_0fc5aac50b1f91b6bbaaae88e08e5a88&quot;,
#                 {
#                     center: [40.02517280312939, -105.2403067513882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0fc5aac50b1f91b6bbaaae88e08e5a88);
#
#
#
#
#
#             var tile_layer_7edf8960574db0d731ec0913f814317c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0fc5aac50b1f91b6bbaaae88e08e5a88);
#
#
#             map_0fc5aac50b1f91b6bbaaae88e08e5a88.fitBounds(
#                 [[39.95421268954864, -105.30572070800108], [40.09613291671013, -105.17489279477535]],
#                 {}
#             );
#
#
#         function geo_json_44b252edf8d66d950817f461be9ae9fe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_44b252edf8d66d950817f461be9ae9fe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_44b252edf8d66d950817f461be9ae9fe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_44b252edf8d66d950817f461be9ae9fe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_44b252edf8d66d950817f461be9ae9fe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_44b252edf8d66d950817f461be9ae9fe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_44b252edf8d66d950817f461be9ae9fe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_44b252edf8d66d950817f461be9ae9fe = L.geoJson(null, {
#                 onEachFeature: geo_json_44b252edf8d66d950817f461be9ae9fe_onEachFeature,
#
#                 style: geo_json_44b252edf8d66d950817f461be9ae9fe_styler,
#                 pointToLayer: geo_json_44b252edf8d66d950817f461be9ae9fe_pointToLayer
#         });
#
#         function geo_json_44b252edf8d66d950817f461be9ae9fe_add (data) {
#             geo_json_44b252edf8d66d950817f461be9ae9fe
#                 .addData(data)
#                 .addTo(map_0fc5aac50b1f91b6bbaaae88e08e5a88);
#         }
#             geo_json_44b252edf8d66d950817f461be9ae9fe_add({&quot;bbox&quot;: [-105.30572070800108, 39.95421268954864, -105.17489279477535, 40.09613291671013], &quot;features&quot;: [{&quot;bbox&quot;: [-105.26075858125914, 40.01736530518096, -105.25577990565736, 40.020717596905335], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.25719594651567, 40.01736530518096], [-105.25577990565736, 40.01887123197258], [-105.25685318496942, 40.0205473833375], [-105.25934256079576, 40.020717596905335], [-105.26075858125914, 40.01921165187717], [-105.25968524629448, 40.01753551151804], [-105.25719594651567, 40.01736530518096]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&qu

# %% [markdown]
# #### Capping and Grouping
# - Huge donations make it hard to visualize contributions. To control for this, a capped contribution variable is created which limits the contribution size to 100. In subsequent modelling steps, we'll control for outliers with greater precision.

# %%
# join hex data
cpf = cpf.sjoin(hexes, how='left')

# turn contributions to float
cpf['Contribution'] = cpf.Contribution.apply(lambda x: float(re.sub('[$(),]', '', x.strip())))

# check the 90th percentile and ceiling the data in a separate column
# this helps control for outliers
cap = cpf.Contribution.quantile(0.90)
print(cap)
cpf['Contribution_Cap'] = cpf.Contribution.apply(lambda x: min(x, cap))

# save data to csv
cpf.to_csv('processed_data.csv', index=False)

# create a groupby for plotting
cpfg = cpf.groupby('hex_id').agg(contribution_total=('Contribution', 'sum'),
                                 capped_total=('Contribution_Cap', 'sum'),
                                 unique_contributions=('ObjectId', 'count')).reset_index()

# add average contribution amounts
cpfg['per_contribution_amt'] = round(cpfg.contribution_total/cpfg.unique_contributions,2)
cpfg['per_contribution_amt_cap'] = round(cpfg.capped_total/cpfg.unique_contributions,2)

# add a geometry column
cpfg['geometry'] = cpfg.hex_id.apply(lambda x: transform(flip, Polygon(h3.cell_to_boundary(x))))
cpfg = gpd.GeoDataFrame(cpfg, geometry='geometry', crs=4326)
# Out:
# 100.0

# %% [markdown]
# #### Unique Contributions

# %%
cpfg.explore('unique_contributions', cmap='RdYlGn')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66d61d09a2ec53e9248f98e4f2408e64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66d61d09a2ec53e9248f98e4f2408e64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66d61d09a2ec53e9248f98e4f2408e64 = L.map(
#                 &quot;map_66d61d09a2ec53e9248f98e4f2408e64&quot;,
#                 {
#                     center: [40.01990130032176, -105.23896296760331],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_66d61d09a2ec53e9248f98e4f2408e64);
#
#
#
#
#
#             var tile_layer_a0f561059a51343d931ca015dade9004 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_66d61d09a2ec53e9248f98e4f2408e64);
#
#
#             map_66d61d09a2ec53e9248f98e4f2408e64.fitBounds(
#                 [[39.962233004966905, -105.29912515982576], [40.07756959567662, -105.17880077538086]],
#                 {}
#             );
#
#
#         function geo_json_02b5f812537e33ec3c5166abaec5d148_styler(feature) {
#             switch(feature.id) {
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;69&quot;: case &quot;101&quot;: case &quot;120&quot;: case &quot;153&quot;: case &quot;190&quot;: case &quot;309&quot;: case &quot;328&quot;: case &quot;337&quot;: case &quot;346&quot;: case &quot;357&quot;: case &quot;360&quot;: case &quot;390&quot;: case &quot;393&quot;:
#                     return {&quot;color&quot;: &quot;#ca2427&quot;, &quot;fillColor&quot;: &quot;#ca2427&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;36&quot;: case &quot;59&quot;: case &quot;77&quot;: case &quot;93&quot;: case &quot;109&quot;: case &quot;117&quot;: case &quot;137&quot;: case &quot;167&quot;: case &quot;327&quot;: case &quot;334&quot;: case &quot;355&quot;: case &quot;359&quot;: case &quot;375&quot;:
#                     return {&quot;color&quot;: &quot;#c62027&quot;, &quot;fillColor&quot;: &quot;#c62027&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;16&quot;: case &quot;24&quot;: case &quot;83&quot;: case &quot;89&quot;: case &quot;108&quot;: case &quot;147&quot;: case &quot;186&quot;: case &quot;212&quot;: case &quot;214&quot;: case &quot;235&quot;: case &quot;237&quot;: case &quot;312&quot;: case &quot;344&quot;:
#                     return {&quot;color&quot;: &quot;#b71126&quot;, &quot;fillColor&quot;: &quot;#b71126&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;45&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;63&quot;: case &quot;91&quot;: case &quot;154&quot;: case &quot;195&quot;: case &quot;220&quot;: case &quot;232&quot;: case &quot;288&quot;: case &quot;301&quot;: case &quot;324&quot;: case &quot;339&quot;: case &quot;342&quot;: case &quot;350&quot;: case &quot;356&quot;: case &quot;362&quot;: case &quot;380&quot;:
#                     return {&quot;color&quot;: &quot;#bb1526&quot;, &quot;fillColor&quot;: &quot;#bb1526&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;40&quot;: case &quot;62&quot;: case &quot;72&quot;: case &quot;76&quot;: case &quot;80&quot;: case &quot;85&quot;: case &quot;88&quot;: case &quot;98&quot;: case &quot;100&quot;: case &quot;110&quot;: case &quot;114&quot;: case &quot;123&quot;: case &quot;135&quot;: case &quot;139&quot;: case &quot;205&quot;: case &quot;208&quot;: case &quot;226&quot;: case &quot;236&quot;: case &quot;257&quot;: case &quot;263&quot;: case &quot;264&quot;: case &quot;295&quot;: case &quot;297&quot;: case &quot;307&quot;: case &quot;315&quot;: case &quot;335&quot;: case &quot;341&quot;: case &quot;348&quot;: case &quot;381&quot;: case &quot;382&quot;: case &quot;383&quot;:
#                     return {&quot;color&quot;: &quot;#ab0626&quot;, &quot;fillColor&quot;: &quot;#ab0626&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;60&quot;: case &quot;84&

# %% [markdown]
# #### Capped Contribution Total

# %%
cpfg.explore('capped_total', cmap='RdYlGn')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3aa133b4812688b65221eb358efb405 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3aa133b4812688b65221eb358efb405&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3aa133b4812688b65221eb358efb405 = L.map(
#                 &quot;map_d3aa133b4812688b65221eb358efb405&quot;,
#                 {
#                     center: [40.01990130032176, -105.23896296760331],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d3aa133b4812688b65221eb358efb405);
#
#
#
#
#
#             var tile_layer_f5ad68e7ce803480667c3d21581810e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3aa133b4812688b65221eb358efb405);
#
#
#             map_d3aa133b4812688b65221eb358efb405.fitBounds(
#                 [[39.962233004966905, -105.29912515982576], [40.07756959567662, -105.17880077538086]],
#                 {}
#             );
#
#
#         function geo_json_8c9499f09e1fb0293b4a2962e8bff027_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;9&quot;: case &quot;35&quot;: case &quot;67&quot;: case &quot;82&quot;: case &quot;87&quot;: case &quot;90&quot;: case &quot;94&quot;: case &quot;107&quot;: case &quot;139&quot;: case &quot;145&quot;: case &quot;194&quot;: case &quot;206&quot;: case &quot;233&quot;: case &quot;258&quot;: case &quot;269&quot;: case &quot;293&quot;: case &quot;306&quot;: case &quot;329&quot;: case &quot;336&quot;: case &quot;347&quot;: case &quot;385&quot;: case &quot;386&quot;:
#                     return {&quot;color&quot;: &quot;#a50026&quot;, &quot;fillColor&quot;: &quot;#a50026&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;310&quot;:
#                     return {&quot;color&quot;: &quot;#c62027&quot;, &quot;fillColor&quot;: &quot;#c62027&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;54&quot;: case &quot;117&quot;: case &quot;232&quot;: case &quot;290&quot;: case &quot;303&quot;: case &quot;324&quot;: case &quot;356&quot;: case &quot;390&quot;:
#                     return {&quot;color&quot;: &quot;#bd1726&quot;, &quot;fillColor&quot;: &quot;#bd1726&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;10&quot;: case &quot;63&quot;: case &quot;79&quot;: case &quot;126&quot;: case &quot;160&quot;: case &quot;167&quot;: case &quot;174&quot;: case &quot;190&quot;: case &quot;242&quot;: case &quot;377&quot;: case &quot;389&quot;:
#                     return {&quot;color&quot;: &quot;#b91326&quot;, &quot;fillColor&quot;: &quot;#b91326&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;43&quot;: case &quot;72&quot;: case &quot;95&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;153&quot;: case &quot;205&quot;: case &quot;217&quot;: case &quot;224&quot;: case &quot;264&quot;: case &quot;292&quot;: case &quot;344&quot;:
#                     return {&quot;color&quot;: &quot;#ab0626&quot;, &quot;fillColor&quot;: &quot;#ab0626&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;317&quot;: case &quot;338&quot;:
#                     return {&quot;color&quot;: &quot;#f47044&quot;, &quot;fillColor&quot;: &quot;#f47044&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;83&quot;: case &quot;154&quot;: case &quot;239&quot;: case &quot;248&quot;: case &quot;268&quot;: case &quot;276&quot;: case &quot;337&quot;: case &quot;380&quot;:
#                     return {&quot;color&quot;: &quot;#b50f26&quot;, &quot;fillColor&quot;: &quot;#b50f26&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;59&quot;: case &quot;127&quot;: case &quot;144&quot;: case &quot;173&quot;: case &quot;197&quot;: case &quot;304&quot;: case &quot;352&quot;: case &quot;359&qu

# %% [markdown]
# #### Capped Average Contribution

# %%
cpfg.explore('per_contribution_amt_cap', cmap='RdYlGn')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8b80e1c439440ce9c5258ed774f3cbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8b80e1c439440ce9c5258ed774f3cbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8b80e1c439440ce9c5258ed774f3cbc = L.map(
#                 &quot;map_b8b80e1c439440ce9c5258ed774f3cbc&quot;,
#                 {
#                     center: [40.01990130032176, -105.23896296760331],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b8b80e1c439440ce9c5258ed774f3cbc);
#
#
#
#
#
#             var tile_layer_f2c49dd83b3fd4977baea99169832be2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8b80e1c439440ce9c5258ed774f3cbc);
#
#
#             map_b8b80e1c439440ce9c5258ed774f3cbc.fitBounds(
#                 [[39.962233004966905, -105.29912515982576], [40.07756959567662, -105.17880077538086]],
#                 {}
#             );
#
#
#         function geo_json_cfcd458355845ef05b2e0fb79484030f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;94&quot;: case &quot;336&quot;: case &quot;386&quot;:
#                     return {&quot;color&quot;: &quot;#cc2627&quot;, &quot;fillColor&quot;: &quot;#cc2627&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;164&quot;: case &quot;187&quot;: case &quot;322&quot;:
#                     return {&quot;color&quot;: &quot;#b7e075&quot;, &quot;fillColor&quot;: &quot;#b7e075&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;84&quot;: case &quot;124&quot;: case &quot;171&quot;: case &quot;373&quot;:
#                     return {&quot;color&quot;: &quot;#fafdb8&quot;, &quot;fillColor&quot;: &quot;#fafdb8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#f26841&quot;, &quot;fillColor&quot;: &quot;#f26841&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;318&quot;:
#                     return {&quot;color&quot;: &quot;#dcf08f&quot;, &quot;fillColor&quot;: &quot;#dcf08f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;25&quot;: case &quot;42&quot;: case &quot;61&quot;: case &quot;72&quot;: case &quot;112&quot;: case &quot;123&quot;: case &quot;128&quot;: case &quot;154&quot;: case &quot;231&quot;: case &quot;262&quot;: case &quot;353&quot;: case &quot;387&quot;: case &quot;391&quot;:
#                     return {&quot;color&quot;: &quot;#fffcba&quot;, &quot;fillColor&quot;: &quot;#fffcba&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;380&quot;:
#                     return {&quot;color&quot;: &quot;#fffebe&quot;, &quot;fillColor&quot;: &quot;#fffebe&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fdad60&quot;, &quot;fillColor&quot;: &quot;#fdad60&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;35&quot;: case &quot;82&quot;: case &quot;213&quot;:
#                     return {&quot;color&quot;: &quot;#ef633f&quot;, &quot;fillColor&quot;: &quot;#ef633f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;104&quot;:
#                     return {&quot;color&quot;: &quot;#fff8b4&quot;, &quot;fillColor&quot;: &quot;#fff8b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#feffbe&quot;, &quot;fillColor&quot;: &quot;#feffbe&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;170&quot;: case &quot;229&quot;:
#                     return {&quot;color&quot;: &quot
